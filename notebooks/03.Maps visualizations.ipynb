# %% [markdown]
# ## 3. Visualisation

# %%
import geopandas as gpd
import matplotlib.pyplot as plt 
import os 
import pathlib

# %%
os.chdir('..')
Path = pathlib.Path().resolve()

# %% [markdown]
# 1. Polygon

# %%
small_areas = gpd.read_file(f'{Path}/data/malmo-pop.shp')
small_areas.head()
# Out:
#       fid       Deso  Age_5  Age6_9  Age10_15  Age16_19  Age20_24  Age25_29  \
# 0  2822.0  1280C1590  125.0    82.0     113.0      83.0      80.0     104.0
# 1  2823.0  1280C1430  332.0   201.0     262.0     141.0     165.0     217.0
# 2  2824.0  1280C1220  128.0    69.0      65.0      34.0      93.0     132.0
# 3  2825.0  1280C1490   76.0    70.0     118.0      92.0     102.0      57.0
# 4  2826.0  1280C1530  220.0    94.0     118.0      74.0     150.0     200.0
#
#    Age30_34  Age35_39  ...  Age45_49  Age50_54  Age55_59  Age60_64  Age65_69  \
# 0      99.0     109.0  ...      99.0     115.0      88.0      93.0     101.0
# 1     212.0     195.0  ...     140.0     139.0     140.0     101.0      75.0
# 2     135.0     109.0  ...      71.0      91.0      91.0     119.0     153.0
# 3      48.0      89.0  ...     108.0     101.0      94.0      80.0      59.0
# 4     196.0     163.0  ...     113.0      81.0     107.0      92.0      77.0
#
#    Age70_74  Age75_79  Age80_w   Total  \
# ...

# %%
small_areas.crs
# Out:
# <Derived Projected CRS: EPSG:3006>
# Name: SWEREF99 TM
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Sweden - onshore and offshore.
# - bounds: (10.03, 54.96, 24.17, 69.07)
# Coordinate Operation:
# - name: SWEREF99 TM
# - method: Transverse Mercator
# Datum: SWEREF99
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
small_areas.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# 2. Lines

# %%
roads = gpd.read_file(f'{Path}/data/malmo-streets.shp')
roads.head()
# Out:
#      osm_id                name      highway waterway aerialway barrier  \
# 0  23440666  Blekingsborgsgatan  residential     None      None    None
# 1  23618297     ÃrtholmsvÃĪgen  residential     None      None    None
# 2  28552693          Kransgatan  residential     None      None    None
# 3  28552694          TÃķrngatan  residential     None      None    None
# 4  28552695   SÃķdertorpsvÃĪgen  residential     None      None    None
#
#   man_made  z_order other_tags  \
# 0     None        3       None
# 1     None        3       None
# 2     None        3       None
# 3     None        3       None
# 4     None        3       None
#
#                                             geometry
# 0  LINESTRING (374183.208 6161017.321, 374184.590...
# 1  LINESTRING (373860.815 6160562.585, 373773.040...
# 2  LINESTRING (373648.221 6160291.937, 373678.893...
# 3  LINESTRING (373520.164 6160333.786, 373548.277...
# 4  LINESTRING (373340.961 6160304.145, 373370.603...

# %%
roads.crs
# Out:
# <Derived Projected CRS: EPSG:3006>
# Name: SWEREF99 TM
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Sweden - onshore and offshore.
# - bounds: (10.03, 54.96, 24.17, 69.07)
# Coordinate Operation:
# - name: SWEREF99 TM
# - method: Transverse Mercator
# Datum: SWEREF99
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
roads.plot(color = 'red', linewidth = 0.2, alpha = 0.8)
# Out:
# <AxesSubplot: >

# %% [markdown]
# 3. Points

# %%
schools = gpd.read_file(f'{Path}/data/preschools.shp')
schools.head()
# Out:
#          BESÖKSADR BESÖKSORT           FIRMABEN             FÖRETAGSN   KOM  \
# 0  VIKINGAGATAN 60     MALMÖ           FÖRSKOLA  MALMÖ MONTESSORISKOL  1280
# 1   KAMRERGATAN 11     MALMÖ               None  JUDISKA FÖRSKOLAN CH  1280
# 2    VANÅSGATAN 66     MALMÖ               None  RUMÄNSKA ORTODOXA FÖ  1280
# 3      GRÖNVÄGEN 6     ARLÖV   FÖRSKOLA GRÖNEBO        BURLÖVS KOMMUN  1231
# 4      KORNVÄGEN 1     ARLÖV  FÖRSKOLA SVENSHÖG        BURLÖVS KOMMUN  1231
#
#   KOMTEXT       POSTADRE00 POSTADRESS POSTNUMMER  \
# 0   Malmö  VIKINGAGATAN 60      MALMÖ      21774
# 1   Malmö   KAMRERGATAN 11      MALMÖ      21156
# 2   Malmö    VANÅSGATAN 66      MALMÖ      21620
# 3  Burlöv           BOX 53      ARLÖV      23221
# 4  Burlöv           BOX 53      ARLÖV      23221
#
#                          geometry
# 0  POINT (371044.000 6162502.000)
# 1  POINT (374769.000 6163245.000)
# 2  POINT (371788.000 6161201.000)
# 3  POINT (379012.000 6166772.000)
# 4  POINT (379450.000 6167390.000)

# %%
schools.plot(markersize=15, color='black', edgecolor='white', alpha=0.8, marker='P')
# Out:
# <AxesSubplot: >

# %% [markdown]
# 4. Multi Layer Maps

# %%
fig, ax = plt.subplots(1,1, figsize=(12,10))

roads.plot(ax=ax, color = 'red', linewidth = 0.2, alpha = 1)
small_areas.plot(ax=ax, color = 'grey', alpha = 0.8)
schools.plot(ax=ax, markersize=15, color='black', edgecolor='white', alpha=0.8, marker='P')

plt.title('Schools in Malmo', fontsize=40, color ='grey')
ax.axis('off')
plt.axis('equal')
plt.show()

# %% [markdown]
# 5. Choropleth Map

# %% [markdown]
# With GeoPandas files we just need to provide column on which we want to plot.

# %%
small_areas.plot()
# Out:
# <AxesSubplot: >

# %%
small_areas.plot(column='Age80_w', figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# We can add additional features to such a maps:
# - legend
# - scheme
# - change color
# - number of class `k`

# %%
fig, ax = plt.subplots(figsize=(12,10)) 

small_areas.plot(column='Age80_w', cmap='Blues', scheme='quantiles', k=6, ax=ax, legend=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# 6. Bubble map

# %% [markdown]
# To represents data as bubbles we first need to represent them as a points

# %%
small_areas_points = small_areas.copy()
small_areas_points['geometry'] = small_areas_points['geometry'].centroid 
small_areas_points.head()
# Out:
#       fid       Deso  Age_5  Age6_9  Age10_15  Age16_19  Age20_24  Age25_29  \
# 0  2822.0  1280C1590  125.0    82.0     113.0      83.0      80.0     104.0
# 1  2823.0  1280C1430  332.0   201.0     262.0     141.0     165.0     217.0
# 2  2824.0  1280C1220  128.0    69.0      65.0      34.0      93.0     132.0
# 3  2825.0  1280C1490   76.0    70.0     118.0      92.0     102.0      57.0
# 4  2826.0  1280C1530  220.0    94.0     118.0      74.0     150.0     200.0
#
#    Age30_34  Age35_39  ...  Age45_49  Age50_54  Age55_59  Age60_64  Age65_69  \
# 0      99.0     109.0  ...      99.0     115.0      88.0      93.0     101.0
# 1     212.0     195.0  ...     140.0     139.0     140.0     101.0      75.0
# 2     135.0     109.0  ...      71.0      91.0      91.0     119.0     153.0
# 3      48.0      89.0  ...     108.0     101.0      94.0      80.0      59.0
# 4     196.0     163.0  ...     113.0      81.0     107.0      92.0      77.0
#
# ...

# %%
small_areas_points.plot()
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(9,9)) 

small_areas_points.plot(ax=ax, color='blue', markersize='Age80_w')
plt.axis('equal') 

plt.show()

# %% [markdown]
# We can add visual context to the bubbles:

# %%
fig, ax = plt.subplots(figsize=(9,9)) 

small_areas.plot(ax=ax, color = 'grey', edgecolor='black', linewidth=0.4)
small_areas_points.plot(ax=ax, color='yellow', markersize='Age80_w', alpha=0.5, categorical=False, legend=True) 

ax.axis('off')
plt.axis('equal')

plt.show()
