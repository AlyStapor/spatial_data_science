# %% [markdown]
# ## 04. Interactive Maps

# %%
import geopandas as gpd 
import folium 
import os 
import pathlib 

os.chdir('..')
path = pathlib.Path().resolve()

# %% [markdown]
# #### 1. Read data

# %%
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')) 
acled = gpd.read_file(f'{path}/data/acled2019.shp', mask = countries[countries['continent'] == 'Africa'])

# %%
acled.head()
# Out:
#    data_id  iso event_id_c  event_id_n        event_date  year  time_preci  \
# 0  6768128  887   YEM45982       45982  31 December 2019  2019           1
# 1  6768129  887   YEM45983       45983  31 December 2019  2019           1
# 2  6768130  887   YEM45984       45984  31 December 2019  2019           1
# 3  6714129  706   SOM30213       30213  31 December 2019  2019           1
# 4  6760978  887   YEM45977       45977  31 December 2019  2019           1
#
#                event_type                sub_event_  \
# 0                 Battles               Armed clash
# 1  Strategic developments  Change to group/activity
# 2                 Battles               Armed clash
# 3                 Battles               Armed clash
# 4  Strategic developments  Change to group/activity
#
#                                               actor1  ... latitude  longitude  \
# 0                   Military Forces of Yemen (2012-)  ...  14.3541    47.0765
# 1  Military Forces of Yemen (2012-) Security Belt...  ...  14.3541    47.0765
# 2                   Military Forces of Yemen (2012-)  ...  14.2081    47.1570
# 3                                         Al Shabaab  ...   2.3963    45.0159
# 4                           Operation Restoring Hope  ...  14.9403    46.6711
#
#   geo_precis                                             source  \
# 0          2  Yemen Data Project; Aden al Ghad; Al Janoob al...
# 1          2              Al Janoob al Youm; Yemen Data Project
# 2          1  Al Janoob al Youm; Aden al Ghad; Yemen Data Pr...
# 3          1                                 Undisclosed Source
# 4          1                 YNP; Yemen Data Project; Al Masdar
#
#                source_sca                                              notes  \
# 0  Local partner-National  On 31 December 2019, clashes reportedly erupte...
# 1  Local partner-National  On 31 December 2019, forces loyal to the South...
# 2  Local partner-National  On 31 December 2019, clashes reportedly erupte...
# 3     Local partner-Other  31 December 2019. In Warmahan, Al Shabaab mili...
# 4  Local partner-National  On 31 December 2019, Sudanese forces reportedl...
#
#   fatalities   timestamp iso3                   geometry
# 0          0  1580761030  YEM  POINT (47.07650 14.35410)
# 1          0  1580761030  YEM  POINT (47.07650 14.35410)
# 2          1  1580761030  YEM  POINT (47.15700 14.20810)
# 3          0  1578512393  SOM   POINT (45.01590 2.39630)
# 4          0  1580153672  YEM  POINT (46.67110 14.94030)
#
# [5 rows x 32 columns]

# %% [markdown]
# #### 2. Base maps

# %%
m = folium.Map(location=[47.07650, 14.35410], zoom_start = 20)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70f06b9624ed20bfda7267ffd030d3cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70f06b9624ed20bfda7267ffd030d3cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70f06b9624ed20bfda7267ffd030d3cd = L.map(
#                 &quot;map_70f06b9624ed20bfda7267ffd030d3cd&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22ae1d61fb211cb9e15f45b0812e75e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70f06b9624ed20bfda7267ffd030d3cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can use other base maps

# %%
location=[47.07650, 14.35410]
m = folium.Map(location=location, tiles="CartoDB dark_matter", zoom_start = 20)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e64472a677c4971ef0709d5483bbebd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e64472a677c4971ef0709d5483bbebd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e64472a677c4971ef0709d5483bbebd3 = L.map(
#                 &quot;map_e64472a677c4971ef0709d5483bbebd3&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28cdeef3619fd5a9455bb0ca6f76f266 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e64472a677c4971ef0709d5483bbebd3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Mark things on the map:

# %%
folium.Marker(location=location, popup='<i> Pinned Place </i>').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d3dfd42e55e94732d795023caa36ae8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d3dfd42e55e94732d795023caa36ae8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d3dfd42e55e94732d795023caa36ae8 = L.map(
#                 &quot;map_7d3dfd42e55e94732d795023caa36ae8&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbd3dec514945be4e1629ad30578f532 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d3dfd42e55e94732d795023caa36ae8);
#
#
#             var marker_4b241d8577bdaab4a85547fad3995667 = L.marker(
#                 [47.0765, 14.3541],
#                 {}
#             ).addTo(map_7d3dfd42e55e94732d795023caa36ae8);
#
#
#         var popup_7a7d656803cf1f4fd854151946f3addf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a25998e050b5e4ba4a3f317f5475accf = $(`&lt;div id=&quot;html_a25998e050b5e4ba4a3f317f5475accf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt; Pinned Place &lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_7a7d656803cf1f4fd854151946f3addf.setContent(html_a25998e050b5e4ba4a3f317f5475accf);
#
#
#
#         marker_4b241d8577bdaab4a85547fad3995667.bindPopup(popup_7a7d656803cf1f4fd854151946f3addf)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding a circle marker:

# %%
folium.Circle(location = location, radius = 25, popup='Marked Circle', color = 'red', fill = False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e64472a677c4971ef0709d5483bbebd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e64472a677c4971ef0709d5483bbebd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e64472a677c4971ef0709d5483bbebd3 = L.map(
#                 &quot;map_e64472a677c4971ef0709d5483bbebd3&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28cdeef3619fd5a9455bb0ca6f76f266 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e64472a677c4971ef0709d5483bbebd3);
#
#
#             var circle_6c2f959b7b43fa35c2c6d43ac7b33db1 = L.circle(
#                 [47.0765, 14.3541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e64472a677c4971ef0709d5483bbebd3);
#
#
#         var popup_121905d4525ec6c5a46288e51f5c236d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ec09632d46a7af1af1bfb1d017ce464 = $(`&lt;div id=&quot;html_4ec09632d46a7af1af1bfb1d017ce464&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marked Circle&lt;/div&gt;`)[0];
#                 popup_121905d4525ec6c5a46288e51f5c236d.setContent(html_4ec09632d46a7af1af1bfb1d017ce464);
#
#
#
#         circle_6c2f959b7b43fa35c2c6d43ac7b33db1.bindPopup(popup_121905d4525ec6c5a46288e51f5c236d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location, zoom_start=2, tiles='cartodbpositron')

folium.GeoJson(acled.sample(1000)).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9699113cd4e2df99465159c87dc5d04f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9699113cd4e2df99465159c87dc5d04f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9699113cd4e2df99465159c87dc5d04f = L.map(
#                 &quot;map_9699113cd4e2df99465159c87dc5d04f&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f6bd7aecca2f600c30f6b061c689368 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9699113cd4e2df99465159c87dc5d04f);
#
#
#
#         function geo_json_fdaa006a94f641ed1135980604267be2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_fdaa006a94f641ed1135980604267be2 = L.geoJson(null, {
#                 onEachFeature: geo_json_fdaa006a94f641ed1135980604267be2_onEachFeature,
#
#         });
#
#         function geo_json_fdaa006a94f641ed1135980604267be2_add (data) {
#             geo_json_fdaa006a94f641ed1135980604267be2
#                 .addData(data)
#                 .addTo(map_9699113cd4e2df99465159c87dc5d04f);
#         }
#             geo_json_fdaa006a94f641ed1135980604267be2_add({&quot;bbox&quot;: [-15.5885, -34.1069, 51.0578, 37.3274], &quot;features&quot;: [{&quot;bbox&quot;: [-12.2833, 11.3182, -12.2833, 11.3182], &quot;geometry&quot;: {&quot;coordinates&quot;: [-12.2833, 11.3182], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7865&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Rioters (Guinea)&quot;, &quot;actor2&quot;: &quot;Police Forces of Guinea (2010-)&quot;, &quot;admin1&quot;: &quot;Labe&quot;, &quot;admin2&quot;: &quot;Labe&quot;, &quot;admin3&quot;: &quot;Labe-Centre&quot;, &quot;assoc_ac_1&quot;: &quot;Journalists (Guinea)&quot;, &quot;assoc_acto&quot;: null, &quot;country&quot;: &quot;Guinea&quot;, &quot;data_id&quot;: 6697324, &quot;event_date&quot;: &quot;20 November 2019&quot;, &quot;event_id_c&quot;: &quot;GUI1218&quot;, &quot;event_id_n&quot;: 1218, &quot;event_type&quot;: &quot;Riots&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 5, &quot;inter2&quot;: 1, &quot;interactio&quot;: 15, &quot;iso&quot;: 324, &quot;iso3&quot;: &quot;GIN&quot;, &quot;latitude&quot;: 11.3182, &quot;location&quot;: &quot;Labe&quot;, &quot;longitude&quot;: -12.2833, &quot;notes&quot;: &quot;On November 20, 2019, a group of young men stoned the Prime Minister\u0027s delegation in the city of Labe (Labe-Centre, Labe), as he was travelling from Tougue. The damaged one vehicle and reportedly injured one member of the press. [size=no report]. They th&quot;, &quot;region&quot;: &quot;Western Africa&quot;, &quot;source&quot;: &quot;Kaba Bachir; Guinee 7; Aminata; Guinee Matin; Africa Guinee&quot;, &quot;source_sca&quot;: &quot;National&quot;, &quot;sub_event_&quot;: &quot;Mob violence&quot;, &quot;time_preci&quot;: 1, &quot;timestamp&quot;: 1576855229, &quot;year&quot;: 2019}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [47.7017, 30.3921, 47.7017, 30.3921], &quot;geometry&quot;: {&quot;coordinates&quot;: [47.7017, 30.3921], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;10223&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Protesters (Iraq)&quot;, &quot;actor2&quot;: null, &quot;admin1&quot;: &quot;Basrah&quot;, &quot;admin2&quot;: &quot;Al-Zubair&quot;, &quot;admin3&quot;: null, &quot;assoc_ac_1&quot;: null, &quot;assoc_acto&quot;: &quot;Students (Iraq)&quot;, &quot;country&quot;: &quot;Iraq&quot;, &quot;data_id&quot;: 6701522, &quot;event_date&quot;: &quot;11 November 2019&quot;, &quot;event_id_c&quot;: &quot;IRQ21943&quot;, &quot;event_id_n&quot;: 21943, &quot;event_type&quot;: &quot;Protests&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 6, &quot;inter2&quot;: 0, &quot;interactio&quot;: 60, &quot;iso&quot;: 368, &quot;iso3&quot;: &quot;IRQ&quot;, &quot;latitude&quot;: 30.3921, &quot;location&quot;: &quot;Al-Zubair&quot;, &quot;longitude&quot;: 47.7017, &quot;notes&quot;: &quot;On Nov 11, student protesters inside a college campus in al-Zubair continued their protests in support of Iraqi protests, and their civil disobedience, and did go to classes during the day. [size=no report]&quot;, &quot;region&quot;: &quot;Middle East&quot;, &quot;source&quot;: &quot;Twitter; Liveuamap&quot;, &quot;source_sca&quot;: &quot;Local partner-New media&quot;, &quot;sub_event_&quot;: &quot;Peaceful protest&quot;, &quot;time_preci&quot;: 1, &quot;timestamp&quot;: 1576855243, &quot;year&quot;: 2019}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [

# %% [markdown]
# Changing marker in `Folium`:

# %%
m = folium.Map(location, zoom_start=2, tiles='cartodbpositron')
acled_sample = acled.sample(1000)
locs_points = zip(acled_sample.geometry.y, acled_sample.geometry.x) 

for location in locs_points:
    folium.CircleMarker(location=location, color='red', radius=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abbdd0bc728e923d21ff518f7c98dda9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abbdd0bc728e923d21ff518f7c98dda9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abbdd0bc728e923d21ff518f7c98dda9 = L.map(
#                 &quot;map_abbdd0bc728e923d21ff518f7c98dda9&quot;,
#                 {
#                     center: [47.0765, 14.3541],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec424e229ee194b5eddfb4f6107b6a24 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_c2cf56340d53a41d17eb712b51b44c5f = L.circleMarker(
#                 [34.025, 45.09],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_d2d6c30c8757bdbe5b69d89dfd6f29ae = L.circleMarker(
#                 [16.2712, 43.1078],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_63bd2e7eb566245c75a9169bc8c36a18 = L.circleMarker(
#                 [13.9363, 43.4555],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_f6aaeb29063fb4f276db7c91528b9ccb = L.circleMarker(
#                 [32.0387, 13.2442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_0d8ca266bf7f9acf41b6344d3d9b748f = L.circleMarker(
#                 [35.1967, 36.4892],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_8f4561c6154bb6bc90836e866bfefa1a = L.circleMarker(
#                 [35.615, 36.6567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abbdd0bc728e923d21ff518f7c98dda9);
#
#
#             var circle_marker_e4f04938f7b1cbcf1ebe1fe72de16556 = L.circleMarker(
#                 [14.7192, 43

# %% [markdown]
# Marker cluster
# - useful when maps need to shrink and expend often

# %%
from folium.plugins import FastMarkerCluster

cmap = folium.Map(location=location, zoom_start=2, tiles='cartodbpositron')

FastMarkerCluster(data=list(zip(acled_sample.geometry.y.values, acled_sample.geometry.x.values))).add_to(cmap)
cmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_934b26ba53bda3b9d3e2f6999736df55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_934b26ba53bda3b9d3e2f6999736df55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_934b26ba53bda3b9d3e2f6999736df55 = L.map(
#                 &quot;map_934b26ba53bda3b9d3e2f6999736df55&quot;,
#                 {
#                     center: [32.2403, 35.4961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74f22e7766bed5fb7ccf99d80aefb8c6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_934b26ba53bda3b9d3e2f6999736df55);
#
#
#             var fast_marker_cluster_bb874364aaa1388677b1d17431bc04fc = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[34.025, 45.09], [16.2712, 43.1078], [13.9363, 43.4555], [32.0387, 13.2442], [35.1967, 36.4892], [35.615, 36.6567], [14.7192, 43.0575], [36.0426, 41.7163], [13.5829, 44.3477], [35.4144, 36.5098], [34.4211, 45.2187], [7.7587, 31.418000000000003], [1.7493, 44.7437], [35.3739, 36.6893], [36.4233, 36.8959], [33.7023, 35.9229], [14.637, 43.0551], [35.5407, 36.7264], [5.7648, 20.6542], [12.0616, 0.3584], [35.5061, 36.5969], [32.7068, 36.568000000000005], [7.2763, 3.1282], [35.5993, 36.579], [35.9428, 39.0519], [36.7525, 3.042], [13.3289, 44.2171], [25.9155, 13.9184], [35.4668, 36.4945], [31.3069, 34.3572], [13.9317, 43.4831], [10.6113, 6.5472], [35.5271, 36.5896], [35.5214, 36.3229], [34.3208, 8.4016], [32.6202, 35.6145], [35.4668, 36.4945], [36.1155, 36.2483], [35.4449, 36.351], [32.6595, 36.433], [29.1268, 15.9477], [34.5169, 35.9683], [33.7243, 44.5345], [-2.5158, 28.8617], [33.5599, 35.3756], [35.5031, 36.5768], [14.753, 42.9763], [-1.2333, 36.7], [9.8891, 6.6278], [33.6781, 44.3467], [35.6353, 36.6331], [6.3045, -0.7263], [1.4382, 29.8447], [32.1942, 48.2436], [11.7898, 34.3599], [31.2035, 45.5643], [17.3971, 43.4774], [35.5407, 36.7264], [-29.8579, 31.0292], [37.1411, 42.3361], [35.5271, 36.5896], [-1.6933, 29.2339], [35.6097, 36.4853], [35.318000000000005, 8.8523], [30.0771, 31.2859], [9.5983, 41.8468], [35.4681, 44.3922], [35.5559, 36.5722], [35.7544, 36.9577], [35.929, 36.6353], [34.4072, 36.0086], [14.5294, 44.8552], [35.927, 35.9891], [14.7383, 0.5986], [36.9897, 35.5121], [4.9834, 7.7414], [26.2097, 50.4597], [35.6131, 36.3625], [32.1722, 13.0203], [32.5056, 45.8247], [35.8922, 36.9877], [35.6727, 36.9659], [35.4395, 36.5361], [35.9924, 36.3934], [35.5499, 36.379], [36.6108, 40.1045], [17.3971, 43.4774], [-24.2216, 46.2078], [35.5232, 36.38], [8.4942, 2.4228], [11.084000000000001, 13.6925], [35.3319, 40.1461], [35.1939, -0.6414], [34.6248, 44.4107], [35.5031, 36.5768], [17.1813, 43.2881], [35.5407, 36.7264], [35.8611, 36.8061], [14.0585, 46.9133], [36.0701, 36.9789], [16.3771, 45.058], [16.9603, 43.7935], [35.929, 36.6353], [12.5782, 7.4347], [-3.0556, 29.6139], [35.8612, 36.9868], [35.3319, 40.1461], [16.2717, -0.0447], [-0.3603, 42.5463], [35.8102, 36.4083], [36.3167, 8.5667], [35.9037, 36.7238], [35.5232, 36.38], [33.7466, 44.6437], [37.0921, 43.4877], [32.1859, 35.2311], [-34.1205, 18.8644], [5.7131, 10.065], [35.7544, 36.9577], [4.7416, 7.0849], [33.0711, 36.1833], [33.3789, 35.4839], [16.3406, 44.5845], [32.0701, 35.2403], [36.1635, 37.0614], [-14.9793, 34.9558], [35.5707, 36.5588], [35.4598, 36.7465], [31.385, 34.459], [36.1926, 44.0106], [35.0114, 40.5047], [0.3859, 41.6181], [33.7451, 35.4645], [1.9167, 30.5], [-3.3797, 29.3639], [35.4203, 36.3633], [34.251, 8.747], [16.9092, 43.2623], [14.0725, 43.1589], [37.07, 40.654], [4.3302, 45.3926], [35.7225, 36.2602], [31.3069, 34.3572], [16.2431, 43.5386], [30.5566, 49.1885], [36.5248, 37.0776], [33.2655, -7.5875], [35.4997, 36.3577], [4.7774, 7.0134], [36.205999999999996, 37.1524], [37.0348, 43.7793], [14.7831, 42.983999999999995], [35.5019, 36.6271], [7.4833, 2.8], [14.7702, 43.071999999999996], [31.9512, 35.2117], [16.9092, 43.2623], [36.0732, 4.7611], [34.0133, -6.8326], [35.7796, 35.9613], [7.2114
