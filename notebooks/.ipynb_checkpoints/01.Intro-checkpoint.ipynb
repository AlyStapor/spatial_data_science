# %% [markdown]
# ## 1. Introduction to GeoPandas

# %% [markdown]
# #### 1. Imports:

# %%
import geopandas as gpd
import pandas as pd
import os
os.chdir('..')
import pathlib

# %%
path = pathlib.Path().resolve()

# %% [markdown]
# Difference between Pandas DataFrame and GeoPandas GeoDataFrame is that second one have to have column `geometry`
# Below is example of GeoDataFrame

# %%
shp_file = f'{path}/data/countries.shp'
shp = gpd.read_file(shp_file)
shp
# Out:
#                         NAME    POP_EST  GDP_MD_EST  POP_YEAR  LASTCENSUS  \
# 0                  Indonesia  260580739   3028000.0      2017        2010
# 1                   Malaysia   31381992    863000.0      2017        2010
# 2                      Chile   17789267    436100.0      2017        2002
# 3                    Bolivia   11138234     78350.0      2017        2001
# 4                       Peru   31036656    410400.0      2017        2007
# ..                       ...        ...         ...       ...         ...
# 250                    Macao     601969     63220.0      2017        2011
# 251  Ashmore and Cartier Is.          0         0.0      2017         -99
# 252          Bajo Nuevo Bank          0         0.0      2017         -99
# 253          Serranilla Bank          0         0.0         0         -99
# 254         Scarborough Reef          0         0.0      2012         -99
#
#      GDP_YEAR                    ECONOMY               INCOME_GRP  \
# 0        2016   4. Emerging region: MIKT   4. Lower middle income
# 1        2016       6. Developing region   3. Upper middle income
# 2        2016    5. Emerging region: G20   3. Upper middle income
# 3        2016    5. Emerging region: G20   4. Lower middle income
# 4        2016    5. Emerging region: G20   3. Upper middle income
# ..        ...                        ...                      ...
# 250      2016       6. Developing region  2. High income: nonOECD
# 251      2016  7. Least developed region            5. Low income
# 252      2016  7. Least developed region            5. Low income
# 253         0  7. Least developed region            5. Low income
# 254      2016  7. Least developed region            5. Low income
#
#          CONTINENT REGION_UN                  SUBREGION  \
# 0             Asia      Asia         South-Eastern Asia
# 1             Asia      Asia         South-Eastern Asia
# 2    South America  Americas              South America
# 3    South America  Americas              South America
# 4    South America  Americas              South America
# ..             ...       ...                        ...
# 250           Asia      Asia               Eastern Asia
# 251        Oceania   Oceania  Australia and New Zealand
# 252  North America  Americas                  Caribbean
# 253  North America  Americas                  Caribbean
# 254           Asia      Asia         South-Eastern Asia
#
#                                               geometry
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# ..                                                 ...
# 250  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...
# 251  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...
# 252  POLYGON ((-79.98929 15.79495, -79.98782 15.796...
# 253  POLYGON ((-78.63707 15.86209, -78.64041 15.864...
# 254  POLYGON ((117.75389 15.15437, 117.75569 15.151...
#
# [255 rows x 12 columns]

# %% [markdown]
# Data types:

# %%
type(shp[['NAME', 'POP_EST']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(shp[['NAME', 'geometry']])
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
shp.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 2. Converting csv into geopandas

# %%
csv_file = f'{path}/data/acled2019.csv'
df = pd.read_csv(csv_file)
df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  6768128  887      YEM45982             45982  31 December 2019  2019
# 1  6768129  887      YEM45983             45983  31 December 2019  2019
# 2  6768130  887      YEM45984             45984  31 December 2019  2019
# 3  6715395  356      IND68948             68948  31 December 2019  2019
# 4  6943236  222        SLV861               861  31 December 2019  2019
#
#    time_precision                  event_type            sub_event_type  \
# 0               1                     Battles               Armed clash
# 1               1      Strategic developments  Change to group/activity
# 2               1                     Battles               Armed clash
# 3               1                    Protests          Peaceful protest
# 4               1  Violence against civilians                    Attack
#
#                                               actor1  ...      location  \
# 0                   Military Forces of Yemen (2012-)  ...        Habban
# 1  Military Forces of Yemen (2012-) Security Belt...  ...        Habban
# 2                   Military Forces of Yemen (2012-)  ...  Wadi Haburah
# 3                                 Protesters (India)  ...   Bhubaneswar
# 4                                    B-18: Barrio-18  ...      Huizucar
#
#    latitude longitude geo_precision  \
# 0   14.3541   47.0765             2
# 1   14.3541   47.0765             2
# 2   14.2081   47.1570             1
# 3   20.2724   85.8338             1
# 4   13.5894  -89.2383             1
#
#                                               source            source_scale  \
# 0  Yemen Data Project; Aden al Ghad; Al Janoob al...  Local partner-National
# 1              Al Janoob al Youm; Yemen Data Project  Local partner-National
# 2  Al Janoob al Youm; Aden al Ghad; Yemen Data Pr...  Local partner-National
# 3                                    Pioneer (India)                National
# 4                                    El Salvador.com                National
#
#                                                notes fatalities   timestamp  \
# 0  On 31 December 2019, clashes reportedly erupte...          0  1580761030
# 1  On 31 December 2019, forces loyal to the South...          0  1580761030
# 2  On 31 December 2019, clashes reportedly erupte...          1  1580761030
# 3  On 31 December, students' wing of INC and Mili...          0  1578514389
# 4  On 31th December 2019 in Huizucar (La Libertad...          1  1582839958
#
#   iso3
# 0  YEM
# 1  YEM
# 2  YEM
# 3  IND
# 4  SLV
#
# [5 rows x 31 columns]

# %%
df.sample(100).plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# We cannot see map above as it is not geopandas file. To convert we may use below function:

# %%
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  6768128  887      YEM45982             45982  31 December 2019  2019
# 1  6768129  887      YEM45983             45983  31 December 2019  2019
# 2  6768130  887      YEM45984             45984  31 December 2019  2019
# 3  6715395  356      IND68948             68948  31 December 2019  2019
# 4  6943236  222        SLV861               861  31 December 2019  2019
#
#    time_precision                  event_type            sub_event_type  \
# 0               1                     Battles               Armed clash
# 1               1      Strategic developments  Change to group/activity
# 2               1                     Battles               Armed clash
# 3               1                    Protests          Peaceful protest
# 4               1  Violence against civilians                    Attack
#
#                                               actor1  ... latitude  longitude  \
# 0                   Military Forces of Yemen (2012-)  ...  14.3541    47.0765
# 1  Military Forces of Yemen (2012-) Security Belt...  ...  14.3541    47.0765
# 2                   Military Forces of Yemen (2012-)  ...  14.2081    47.1570
# 3                                 Protesters (India)  ...  20.2724    85.8338
# 4                                    B-18: Barrio-18  ...  13.5894   -89.2383
#
#   geo_precision                                             source  \
# 0             2  Yemen Data Project; Aden al Ghad; Al Janoob al...
# 1             2              Al Janoob al Youm; Yemen Data Project
# 2             1  Al Janoob al Youm; Aden al Ghad; Yemen Data Pr...
# 3             1                                    Pioneer (India)
# 4             1                                    El Salvador.com
#
#              source_scale                                              notes  \
# 0  Local partner-National  On 31 December 2019, clashes reportedly erupte...
# 1  Local partner-National  On 31 December 2019, forces loyal to the South...
# 2  Local partner-National  On 31 December 2019, clashes reportedly erupte...
# 3                National  On 31 December, students' wing of INC and Mili...
# 4                National  On 31th December 2019 in Huizucar (La Libertad...
#
#   fatalities   timestamp iso3                    geometry
# 0          0  1580761030  YEM   POINT (47.07650 14.35410)
# 1          0  1580761030  YEM   POINT (47.07650 14.35410)
# 2          1  1580761030  YEM   POINT (47.15700 14.20810)
# 3          0  1578514389  IND   POINT (85.83380 20.27240)
# 4          1  1582839958  SLV  POINT (-89.23830 13.58940)
#
# [5 rows x 32 columns]

# %%
gdf.plot(markersize=2)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 3. Saving gpd file
#
# crs is coordinate reference system
# For example, one of the most commonly used CRS is the WGS84 latitude-longitude projection. This can be referred to using the authority code "EPSG:4326".
# More: https://geopandas.org/en/stable/docs/user_guide/projections.html

# %%
path_outputs = f'{path}/outputs' 
gdf.to_file(f'{path_outputs}/acled2019.shp', crs={'init':"epsg:4326"})
# Out:
# /var/folders/2f/c6skwjt96m984f45rzp9_qw40000gn/T/ipykernel_60576/231140029.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(f'{path_outputs}/acled2019.shp', crs={'init':"epsg:4326"})
# /Applications/anaconda3/envs/spatial/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# To check format we can use `.csr` method

# %%
shp.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### 4. Saving as geojson

# %%
gdf.sample(5000).to_file(f'{path_outputs}/aucled2019.geojson', driver='GeoJSON')

# %% [markdown]
# #### 5. Working on subsets of data:

# %%
shp[shp.CONTINENT == 'Africa'].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Reading `.shp` file with mask created above:

# %%
africa = gpd.read_file(f'{path_outputs}/acled2019.shp', mask = shp[shp.CONTINENT == 'Africa'])
africa.plot(markersize=0.5)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Subsets of rows:

# %%
subset = gpd.read_file(f'{path_outputs}/acled2019.shp', rows = 200)
subset.plot()
# Out:
# <AxesSubplot: >

# %%
subset = subset = gpd.read_file(f'{path_outputs}/acled2019.shp', rows = slice(200,500)) 
subset.plot()
# Out:
# <AxesSubplot: >
